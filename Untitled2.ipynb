# %%
# !git clone https://github.com/trybushenko/Fairface-Face-Classification.git
# Out:
# Cloning into 'Fairface-Face-Classification'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 65 (delta 0), reused 3 (delta 0), pack-reused 59 (from 1)
# Receiving objects: 100% (65/65), 19.58 MiB | 18.04 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !cd Fairface-Face-Classification/

# %%
# !cd /content/Fairface-Face-Classification/

# %%
# !sh Fairface-Face-Classification/runthis.sh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 kB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 53.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: keyring
#     Found existing installation: keyring 23.5.0
#     Uninstalling keyring-23.5.0:
#       Successfully uninstalled keyring-23.5.0
# ...
#
# Poetry could not find a pyproject.toml file in /content or its parents
#
# Poetry could not find a pyproject.toml file in /content or its parents
#
# ...

# %%
# !python /content/Fairface-Face-Classification/fairface_classification/inference.py
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 139MB/s]
# Traceback (most recent call last):
#   File "/content/Fairface-Face-Classification/fairface_classification/inference.py", line 28, in <module>
#     test_dataset = ImageFolder(test_dir, transform=transform)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 328, in __init__
#     super().__init__(
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 149, in __init__
#     classes, class_to_idx = self.find_classes(self.root)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 234, in find_classes
#     return find_classes(directory)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 41, in find_classes
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.1'

# %%
print(tf.__version__)
print(tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.17.1
# /device:GPU:0
# Num GPUs Available:  1

# %%
import gdown
train_csv_url = "https://drive.google.com/uc?id=1i1L3Yqwaio7YSOCj7ftgk8ZZchPG7dmH"
val_csv_url = "https://drive.google.com/uc?id=1wOdja-ezstMEp81tX1a-EYkFebev4h7D"

# Download the files
gdown.download(train_csv_url, "fairface_label_train.csv", quiet=False)
gdown.download(val_csv_url, "fairface_label_val.csv", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1i1L3Yqwaio7YSOCj7ftgk8ZZchPG7dmH
# To: /content/fairface_label_train.csv
# 100%|██████████| 3.79M/3.79M [00:00<00:00, 276MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1wOdja-ezstMEp81tX1a-EYkFebev4h7D
# To: /content/fairface_label_val.csv
# 100%|██████████| 448k/448k [00:00<00:00, 95.3MB/s]
# 'fairface_label_val.csv'

# %%
import pandas as pd

train_df = pd.read_csv("fairface_label_train.csv")
val_df = pd.read_csv("fairface_label_val.csv")

print(train_df.head())
print(val_df.head())
# Out:
#           file    age  gender        race  service_test
# 0  train/1.jpg  50-59    Male  East Asian          True
# 1  train/2.jpg  30-39  Female      Indian         False
# 2  train/3.jpg    3-9  Female       Black         False
# 3  train/4.jpg  20-29  Female      Indian          True
# 4  train/5.jpg  20-29  Female      Indian          True
#         file    age  gender             race  service_test
# 0  val/1.jpg    3-9    Male       East Asian         False
# 1  val/2.jpg  50-59  Female       East Asian          True
# 2  val/3.jpg  30-39    Male            White          True
# 3  val/4.jpg  20-29  Female  Latino_Hispanic          True
# 4  val/5.jpg  20-29    Male  Southeast Asian         False

# %%
train_images_url = "https://drive.google.com/uc?id=1Z1RqRo0_JiavaZw2yzZG6WETdZQ8qX86"  # Training images

# Download the image zip files
gdown.download(train_images_url, "train.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Z1RqRo0_JiavaZw2yzZG6WETdZQ8qX86
# From (redirected): https://drive.google.com/uc?id=1Z1RqRo0_JiavaZw2yzZG6WETdZQ8qX86&confirm=t&uuid=0c770422-af81-43ca-82bc-1c76eaadeaf0
# To: /content/train.zip
# 100%|██████████| 578M/578M [00:08<00:00, 65.1MB/s]
# 'train.zip'

# %%
import zipfile

# Unzip training images
with zipfile.ZipFile("train.zip", "r") as zip_ref:
    zip_ref.extractall("train")

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import os, random, cv2
# %matplotlib inline
labels_map = {}
inv_labels_map = {}
count = 0
num_samples=0
for label in val_df['race']:
  num_samples=num_samples+1
  if(label in labels_map):
    continue
  labels_map[label] = count
  inv_labels_map[count] = label
  count=count+1
print("Label Map: ", labels_map)
print("No. of Labels are: ", count)
print("Total No. of samples",num_samples)
labels_count = {}
for label in val_df['race']:
  if(label in labels_count):
    labels_count[label] = labels_count[label] + 1
  else:
    labels_count[label] = 0
print(labels_count)
plt.figure(figsize=(40,10))
plt.bar(list(labels_count.keys()), list(labels_count.values()),width=0.6)
plt.xticks(rotation = 45, fontsize=60)
plt.show()
# Out:
# Label Map:  {'East Asian': 0, 'White': 1, 'Latino_Hispanic': 2, 'Southeast Asian': 3, 'Black': 4, 'Indian': 5, 'Middle Eastern': 6}
# No. of Labels are:  7
# Total No. of samples 10954
# {'East Asian': 1549, 'White': 2084, 'Latino_Hispanic': 1622, 'Southeast Asian': 1414, 'Black': 1555, 'Indian': 1515, 'Middle Eastern': 1208}

# %%
example_img = random.choice(os.listdir("/content/train/train"))
print("Label:", train_df.loc[train_df['file'] == example_img[:-4]]['race'].all())
example_img = plt.imread("train/train/"+example_img)
plt.grid(False)
plt.imshow(example_img)
print("Shape of the image is:", example_img.shape)
print("Max:", example_img.max(), ", Min:", example_img.min())
# Out:
# Label: True
# Shape of the image is: (224, 224, 3)
# Max: 223 , Min: 4

# %%
# !pip install gdown tensorflow

import gdown
import tensorflow as tf

# Google Drive file ID for the pretrained model
file_id = '1-0UJVSx3BMiEJDi8U51R2z4t6LNDd4G6'

# Download the model file
gdown.download(id=file_id, output="pretrained_model.h5", quiet=False)

# Load the model using TensorFlow/Keras
tf.keras.initializers.GlorotUniform
# Now you can use the 'model' variable for inference or further training
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1-0UJVSx3BMiEJDi8U51R2z4t6LNDd4G6
# From (redirected): https://drive.google.com/uc?id=1-0UJVSx3BMiEJDi8U51R2z4t6LNDd4G6&confirm=t&uuid=58d0df5a-9f28-4871-804a-07320eb18045
# To: /content/pretrained_model.h5
# 100%|██████████| 167M/167M [00:03<00:00, 47.5MB/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/operation.py in from_config(cls, config)
#     233         try:
# --> 234             return cls(**config)
#     235         except Exception as e:
#
# ...

# %%
for layer in model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = True
for layer in model.layers:
        if hasattr(layer, 'moving_mean') and hasattr(layer, 'moving_variance'):
            layer.trainable = True
            K.eval(K.update(layer.moving_mean, K.zeros_like(layer.moving_mean)))
            K.eval(K.update(layer.moving_variance, K.zeros_like(layer.moving_variance)))
        else:
            layer.trainable = False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-6cb690bcd148> in <cell line: 1>()
# ----> 1 for layer in model.layers:
#       2     if isinstance(layer, BatchNormalization):
#       3         layer.trainable = True
#       4     else:
#       5         layer.trainable = True
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.layers import Dense,GlobalMaxPooling2D,Flatten,Dropout,BatchNormalization,InputLayer
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras import backend as K
from tensorflow.keras.applications.xception import Xception,preprocess_input
reduce=ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_delta=1E-7)
# Remove the 'layers' argument from Xception instantiation
nn=Xception(include_top=False, weights='imagenet',input_shape=(224,224,3),pooling='avg')
nn.trainable = True
for layer in nn.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False
output=Dense(7,activation='softmax')(nn.output)
model=Model(nn.input,output)
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(0.001),
              metrics=['accuracy'])

layers = [(layer, layer.name, layer.trainable) for layer in model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                             Layer Type  \
# 0          <InputLayer name=input_layer_1, built=True>
# 1               <Conv2D name=block1_conv1, built=True>
# 2    <BatchNormalization name=block1_conv1_bn, buil...
# 3       <Activation name=block1_conv1_act, built=True>
# 4               <Conv2D name=block1_conv2, built=True>
# ..                                                 ...
# 129  <SeparableConv2D name=block14_sepconv2, built=...
# 130  <BatchNormalization name=block14_sepconv2_bn, ...
# 131  <Activation name=block14_sepconv2_act, built=T...
# 132  <GlobalAveragePooling2D name=global_average_po...
# 133                   <Dense name=dense_1, built=True>
#
#                      Layer Name  Layer Trainable
# 0                 input_layer_1            False
# 1                  block1_conv1            False
# 2               block1_conv1_bn             True
# 3              block1_conv1_act            False
# 4                  block1_conv2            False
# ...

# %%
nn.trainable = True
for layer in nn.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(0.005),
              metrics=['accuracy'])

layers = [(layer, layer.name, layer.trainable) for layer in model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                             Layer Type  \
# 0          <InputLayer name=input_layer_1, built=True>
# 1               <Conv2D name=block1_conv1, built=True>
# 2    <BatchNormalization name=block1_conv1_bn, buil...
# 3       <Activation name=block1_conv1_act, built=True>
# 4               <Conv2D name=block1_conv2, built=True>
# ..                                                 ...
# 129  <SeparableConv2D name=block14_sepconv2, built=...
# 130  <BatchNormalization name=block14_sepconv2_bn, ...
# 131  <Activation name=block14_sepconv2_act, built=T...
# 132  <GlobalAveragePooling2D name=global_average_po...
# 133                   <Dense name=dense_1, built=True>
#
#                      Layer Name  Layer Trainable
# 0                 input_layer_1            False
# 1                  block1_conv1            False
# 2               block1_conv1_bn             True
# 3              block1_conv1_act            False
# 4                  block1_conv2            False
# ...

# %%
from tensorflow.keras.models import load_model
model = load_model('pretrained_model.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/operation.py in from_config(cls, config)
#     233         try:
# --> 234             return cls(**config)
#     235         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/separable_conv2d.py in __init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, depth_multiplier, activation, use_bias, depthwise_initializer, pointwise_initializer, bias_initializer, depthwise_regularizer, pointwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, pointwise_constraint, bias_constraint, **kwargs)
#     121     ):
# --> 122         super().__init__(
#     123             rank=2,
#
# ...

# %%
# !pip install h5py

# %%
import h5py

with h5py.File('pretrained_model.h5', 'r') as f:
    # Get the layer configuration data
    layer_configs = f['model_config']['config']['layers']

    # Iterate through the layers and find the index of SeparableConv2D
    for i, layer_config in enumerate(layer_configs):
        if layer_config.attrs['class_name'] == 'SeparableConv2D':
            separable_conv2d_index = i
            print(f"Index of SeparableConv2D layer: {separable_conv2d_index}")
            break  # Stop after finding the first SeparableConv2D layer
    else:
        print("No SeparableConv2D layer found in the model.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-4798861f4427> in <cell line: 3>()
#       3 with h5py.File('pretrained_model.h5', 'r') as f:
#       4     # Get the layer configuration data
# ----> 5     layer_configs = f['model_config']['config']['layers']
#       6
#       7     # Iterate through the layers and find the index of SeparableConv2D
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/group.py in __getitem__(self, name)
#     355                 raise ValueError("Invalid HDF5 object reference")
#     356         elif isinstance(name, (bytes, str)):
# --> 357             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358         else:
# ...

# %%
pip install datasets pandas scikit-learn opencv-python pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 35.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from datasets import load_dataset
from PIL import Image
from skimage.feature import hog
from skimage import exposure

# %%
dataset = load_dataset("HuggingFaceM4/FairFace", '0.25')
df = pd.DataFrame(dataset['train'])

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['image', 'age', 'gender', 'race', 'service_test'], dtype='object')
#                                                image  age  gender  race  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...    6       0     0
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...    4       1     1
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...    1       1     2
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...    3       1     1
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=...    3       1     1
#
#    service_test
# 0          True
# 1         False
# 2         False
# 3          True
# 4          True

# %%
df['label'] = df['race'].apply(lambda x: 1 if x ==2 else 0);

# %%
def preprocess_image(image):
  image = image.convert('L')
  image = image.resize((224, 224))
  image = np.array(image)
  return image


df['image'] = df['image'].apply(preprocess_image)

print(f"Number of samples after prprocessing: {len(df)}")
# Out:
# Number of samples after prprocessing: 86744

# %%
df_subset = df.sample(n=7000, random_state=42)
x = np.array(df_subset['image'].tolist())
y = np.array(df_subset['label'].tolist())
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"Training set size: {len(X_train)}, Test set size: {len(X_test)}")
print(f"Shape of an image: {X_train[0].shape}")
# Out:
# Training set size: 5600, Test set size: 1400
# Shape of an image: (224, 224)

# %%
from skimage.color import rgb2gray

gray_image = rgb2gray(your_image)
fd = hog(gray_image, orientations=8, pixels_per_cell=(16, 16),
         cells_per_block=(1, 1), visualize=True) # multichannel removed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-d3ceef69b6c7> in <cell line: 3>()
#       1 from skimage.color import rgb2gray
#       2
# ----> 3 gray_image = rgb2gray(your_image)
#       4 fd = hog(gray_image, orientations=8, pixels_per_cell=(16, 16),
#       5          cells_per_block=(1, 1), visualize=True) # multichannel removed
#
# NameError: name 'your_image' is not defined

# %%
def extract_hog_features(images):
    features = []
    for i, image in enumerate(images):
        if len(image.shape) == 2:  # Ensure the image is grayscale
            image = np.uint8(image)  # Ensure the image is in the correct format
            if image.shape == (224, 224):  # Ensure the image is the expected size
                try:
                    fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16),  # Changed to integers
                                        cells_per_block=(2, 2), visualize=True)  # Removed multichannel=False
                    features.append(fd)
                except Exception as e:
                    print(f"Error computing HOG for image at index {i}: {e}")
                    continue
            else:
                print(f"Unexpected image size at index {i}: {image.shape}")
        else:
            print(f"Unexpected image shape at index {i}: {image.shape}")
    return np.array(features)
X_train_hog = extract_hog_features(X_train)
X_test_hog = extract_hog_features(X_test)

# %%
import skimage
print(skimage.__version__)
# Out:
# 0.24.0

# %%
print(f"Shape of HOG features for training set: {X_train_hog.shape}")
print(f"Shape of HOG features for test set: {X_test_hog.shape}")
# Out:
# Shape of HOG features for training set: (5600, 5408)
# Shape of HOG features for test set: (1400, 5408)

# %%
scaler = StandardScaler()
X_train_hog = scaler.fit_transform(X_train_hog)
X_test_hog = scaler.transform(X_test_hog)

# %%
model = RandomForestClassifier(n_estimators=10, random_state=42)
model.fit(X_train_hog, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %%
y_pred = model.predict(X_test_hog)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 85.29%

# %%
incorrect_predictions = sum(y_pred != y_test)
print(f'Number of incorrect predictions: {incorrect_predictions}')
# Out:
# Number of incorrect predictions: 206

# %%
# Calculate training accuracy
y_train_pred = model.predict(X_train_hog)
train_accuracy = accuracy_score(y_train, y_train_pred)

# Test accuracy is already calculated
test_accuracy = accuracy_score(y_test, y_pred)

print(f'Training Accuracy: {train_accuracy * 100:.2f}%')
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Training Accuracy: 97.82%
# Test Accuracy: 85.29%

# %%
import matplotlib.pyplot as plt

# Accuracy values
accuracy_values = [train_accuracy * 100, test_accuracy * 100]
labels = ['Training', 'Test']

# Plot
plt.figure(figsize=(8, 6))
plt.bar(labels, accuracy_values, color=['blue', 'orange'])
plt.title('FairFace Model Accuracy')
plt.ylabel('Accuracy (%)')
plt.ylim(0, 100)  # Accuracy ranges from 0% to 100%
plt.show()

# %%
import cv2
from google.colab.patches import cv2_imshow
def get_human_feedback(image):
    # Display the image using OpenCV
    cv2_imshow(image)
    cv2.waitKey(1)  # Display the image for a short time

    # Get user input
    feedback = input("Is the person Black? (y/n): ").strip().lower()
    cv2.destroyAllWindows()

    if feedback == 'y':
        return 1
    elif feedback == 'n':
        return 0
    else:
        print("Invalid input. Please enter 'y' or 'n'.")
        return get_human_feedback(image)

# %%
def human_feedback(pred, true_label, image):
    if pred == true_label:
        return 'correct'
    else:
        human_feedback = get_human_feedback(image)
        return 'correct' if human_feedback == true_label else 'incorrect'

# Randomly select 30 incorrect predictions for feedback
incorrect_indices = np.where(y_pred != y_test)[0]
np.random.shuffle(incorrect_indices)
limited_feedback_indices = incorrect_indices[:30]

# Apply human feedback collection to the selected incorrect predictions
feedback = [human_feedback(y_pred[i], y_test[i], X_test[i]) for i in limited_feedback_indices]
# Out:
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): y
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): y
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): y
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): y
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): y
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): n
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): y
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): y
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): y
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): y
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): n
# <PIL.Image.Image image mode=L size=224x224>
# Is the person Black? (y/n): n
# <PIL.Image.Image image mode=L size=224x224>
# ...

# %%
def reward_function(feedback):
    return 1 if feedback == 'correct' else -1

rewards = [reward_function(f) for f in feedback]

# %%
for i, idx in enumerate(limited_feedback_indices):
    if rewards[i] == -1:
        X_train_hog = np.vstack([X_train_hog, X_test_hog[idx]])
        y_train = np.hstack([y_train, y_test[idx]])
model.fit(X_train_hog, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %%
y_pred_updated = model.predict(X_test_hog)
accuracy_updated = accuracy_score(y_test, y_pred_updated)
print(f'Updated Accuracy: {accuracy_updated * 100:.2f}%')
# Out:
# Updated Accuracy: 86.07%

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
from datasets import load_dataset
import numpy as np

# Load the UTKFace dataset
dataset = load_dataset("tiennv/utkface")

# Split into training and test sets
train_data = dataset['train']
test_data = dataset['test']

# %%
# Helper function to safely process labels
def process_label(label):
    parts = label.split("_")
    if len(parts) > 1 and parts[1].isdigit():  # Ensure the second part is present and is a digit
        return int(parts[1])
    else:
        return None  # Return None for invalid labels

# Process the labels
train_labels = np.array([process_label(example['label']) for example in train_data])
test_labels = np.array([process_label(example['label']) for example in test_data])

# Filter out None values from labels and corresponding entries in images
valid_train_indices = [i for i, label in enumerate(train_labels) if label is not None]
valid_test_indices = [i for i, label in enumerate(test_labels) if label is not None]

train_images = np.array([example['embd'] for i, example in enumerate(train_data) if i in valid_train_indices])
train_labels = train_labels[valid_train_indices]

test_images = np.array([example['embd'] for i, example in enumerate(test_data) if i in valid_test_indices])
test_labels = test_labels[valid_test_indices]

# Confirm successful extraction
print(f"Training images shape: {train_images.shape}, Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}, Test labels shape: {test_labels.shape}")
# Out:
# Training images shape: (18682, 512), Training labels shape: (18682,)
# Test images shape: (2076, 512), Test labels shape: (2076,)

# %%
# Ensure all labels are integers
valid_classes = [0, 1]  # Adjust based on your dataset
train_labels = train_labels.astype(int)
test_labels = test_labels.astype(int)

# Remove invalid classes if needed
train_mask = np.isin(train_labels, valid_classes)
test_mask = np.isin(test_labels, valid_classes)

train_images = train_images[train_mask]
train_labels = train_labels[train_mask]
test_images = test_images[test_mask]
test_labels = test_labels[test_mask]

print(f"Cleaned training labels: {np.unique(train_labels)}")
print(f"Cleaned test labels: {np.unique(test_labels)}")
# Out:
# Cleaned training labels: [0 1]
# Cleaned test labels: [0 1]

# %%
rf_model.fit(train_images, train_labels)

# Evaluate the model
y_pred = rf_model.predict(test_images)
initial_accuracy = accuracy_score(test_labels, y_pred)

print(f"Initial Accuracy: {initial_accuracy * 100:.2f}%")
# Out:
# Initial Accuracy: 84.53%

# %%
from sklearn.metrics import accuracy_score

# Overall accuracy
overall_accuracy = accuracy_score(test_labels, y_pred)
print(f"Overall Accuracy: {overall_accuracy * 100:.2f}%")

# Map race labels to group names
race_mapping = {0: "Non-Black", 1: "Black"}  # Adjust based on dataset

# Group-specific accuracy
group_accuracies = {}
for race, name in race_mapping.items():
    group_indices = np.where(test_labels == race)[0]
    if len(group_indices) > 0:  # Ensure the group has samples
        group_accuracy = accuracy_score(test_labels[group_indices], y_pred[group_indices])
        group_accuracies[name] = group_accuracy
    else:
        group_accuracies[name] = None  # No samples in this group

# Print group-specific accuracies
print("Group-Specific Accuracies:")
for group, accuracy in group_accuracies.items():
    if accuracy is not None:
        print(f"{group}: {accuracy * 100:.2f}%")
    else:
        print(f"{group}: No samples in test set")
# Out:
# Overall Accuracy: 84.53%
# Group-Specific Accuracies:
# Non-Black: 87.38%
# Black: 81.59%

# %%
import matplotlib.pyplot as plt

# Data for the bar plot
groups = list(group_accuracies.keys())
accuracies = [group_accuracies[group] * 100 if group_accuracies[group] is not None else 0 for group in groups]

# Plot
plt.figure(figsize=(10, 6))
plt.bar(groups, accuracies, color='skyblue')
plt.title("Group-Specific Accuracies")
plt.xlabel("Groups")
plt.ylabel("Accuracy (%)")
plt.ylim(0, 100)
plt.show()

# %%
import random

def get_human_feedback(pred, true_label):
    """
    Simulate human feedback. If prediction is incorrect, return the correct label.
    """
    if pred == true_label:
        return 'correct'
    else:
        # Simulate a user correcting the label
        return true_label if random.random() > 0.1 else pred  # Assume 90% user accuracy

# %%
import numpy as np

# Identify incorrect predictions
incorrect_indices = np.where(y_pred != test_labels)[0]
print(f"Number of incorrect predictions: {len(incorrect_indices)}")

# Randomly sample a subset of incorrect predictions for feedback
sampled_indices = np.random.choice(incorrect_indices, size=min(30, len(incorrect_indices)), replace=False)
feedback_labels = []

# Collect feedback for sampled incorrect predictions
for idx in sampled_indices:
    feedback = get_human_feedback(y_pred[idx], test_labels[idx])
    feedback_labels.append(feedback)
# Out:
# Number of incorrect predictions: 321

# %%
# Update the training set with corrected feedback
new_features = test_images[sampled_indices]
new_labels = np.array(feedback_labels)

# Add new samples to the training set
train_images = np.vstack([train_images, new_features])
train_labels = np.hstack([train_labels, new_labels])

print(f"Updated training set size: {len(train_images)}")
# Out:
# Updated training set size: 18712

# %%
# Retrain the model
rf_model.fit(train_images, train_labels)

# Re-evaluate the model
y_pred_updated = rf_model.predict(test_images)
accuracy_updated = accuracy_score(test_labels, y_pred_updated)

print(f"Updated Accuracy After RLHF: {accuracy_updated * 100:.2f}%")
# Out:
# Updated Accuracy After RLHF: 85.93%

# %%
# Group-specific accuracies after RLHF
group_accuracies_updated = {}
for race, name in race_mapping.items():
    group_indices = np.where(test_labels == race)[0]
    if len(group_indices) > 0:  # Ensure the group has samples
        group_accuracy = accuracy_score(test_labels[group_indices], y_pred_updated[group_indices])
        group_accuracies_updated[name] = group_accuracy
    else:
        group_accuracies_updated[name] = None

# Print group-specific accuracies
print("Group-Specific Accuracies After RLHF:")
for group, accuracy in group_accuracies_updated.items():
    if accuracy is not None:
        print(f"{group}: {accuracy * 100:.2f}%")
    else:
        print(f"{group}: No samples in test set")
# Out:
# Group-Specific Accuracies After RLHF:
# Non-Black: 88.71%
# Black: 83.06%

# %%
# Data for the bar plot
groups = list(group_accuracies_updated.keys())
accuracies_updated = [group_accuracies_updated[group] * 100 if group_accuracies_updated[group] is not None else 0 for group in groups]

# Plot
plt.figure(figsize=(10, 6))
plt.bar(groups, accuracies_updated, color='lightcoral')
plt.title("Group-Specific Accuracies After RLHF")
plt.xlabel("Groups")
plt.ylabel("Accuracy (%)")
plt.ylim(0, 100)
plt.show()

# %%
from sklearn.metrics import classification_report

# Generate a classification report
report = classification_report(test_labels, test_predictions, target_names=["Non-Black", "Black"])
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    Non-Black       0.83      0.87      0.85      1054
#        Black       0.86      0.82      0.84      1021
#
#     accuracy                           0.84      2075
#    macro avg       0.85      0.84      0.84      2075
# weighted avg       0.85      0.84      0.84      2075

# %%
import joblib

# Save the model
joblib.dump(model, "racial_detection_model.pkl")
print("Model saved as 'racial_detection_model.pkl'")
# Out:
# Model saved as 'racial_detection_model.pkl'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Feature importance
importances = model.feature_importances_
indices = np.argsort(importances)[-10:]  # Top 10 features

# Plot
plt.figure(figsize=(10, 6))
plt.barh(range(len(indices)), importances[indices], align="center")
plt.yticks(range(len(indices)), indices)
plt.xlabel("Feature Importance")
plt.title("Top 10 Important Features")
plt.show()

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np

# Generate the classification report as a dictionary
report_dict = classification_report(test_labels, test_predictions, target_names=["Non-Black", "Black"], output_dict=True)

# Extract metrics
categories = ["Non-Black", "Black"]
metrics = ["precision", "recall", "f1-score"]

values = {metric: [report_dict[cat][metric] for cat in categories] for metric in metrics}

# Print extracted metrics
for metric, vals in values.items():
    print(f"{metric.capitalize()} - Non-Black: {vals[0]:.2f}, Black: {vals[1]:.2f}")
# Out:
# Precision - Non-Black: 0.83, Black: 0.86
# Recall - Non-Black: 0.87, Black: 0.82
# F1-score - Non-Black: 0.85, Black: 0.84

# %%
import matplotlib.pyplot as plt

# Accuracy values for both models
datasets = ['FairFace', 'UTKFace']
accuracies = [86, 84]  # Accuracy percentages

# Plot the accuracies
plt.figure(figsize=(8, 5))
plt.bar(datasets, accuracies, color=['blue', 'orange'])

# Add labels and title
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Comparison: FairFace vs. UTKFace')
plt.ylim(0, 100)  # Set y-axis limit to 100%
plt.text(0, accuracies[0] + 1, f"{accuracies[0]}%", ha='center', fontsize=12)  # Annotate FairFace
plt.text(1, accuracies[1] + 1, f"{accuracies[1]}%", ha='center', fontsize=12)  # Annotate UTKFace

# Show the plot
plt.tight_layout()
plt.show()
